# %% [markdown]
# # Module 7 Assignment

# %% [markdown]
# A few things you should keep in mind when working on assignments:
#
# 1. Make sure you fill in any place that says `YOUR CODE HERE`. Do **not** write your answer in anywhere else other than where it says `YOUR CODE HERE`. Anything you write anywhere else will be removed or overwritten by the autograder.
#
# 2. Before you submit your assignment, make sure everything runs as expected. Go to menubar, select _Kernel_, and restart the kernel and run all cells (_Restart & Run all_).
#
# 3. Do not change the title (i.e. file name) of this notebook.
#
# 4. Make sure that you save your work (in the menubar, select _File_ → _Save and CheckPoint_)

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats as st
from nose.tools import assert_equal, assert_almost_equal
from nose.tools import assert_equal, assert_is_instance, assert_is_not
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# In the following problems we will use the dow jones index data

# %%
df = pd.read_csv('dow_jones_index.data')
df.head()
# Out:
#    quarter stock       date   open   high    low  close     volume  \
# 0        1    AA   1/7/2011  15.82  16.72  15.78  16.42  239655616
# 1        1    AA  1/14/2011  16.71  16.71  15.64  15.97  242963398
# 2        1    AA  1/21/2011  16.19  16.38  15.60  15.79  138428495
# 3        1    AA  1/28/2011  15.87  16.63  15.82  16.13  151379173
# 4        1    AA   2/4/2011  16.18  17.39  16.18  17.14  154387761
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0               3.79267                                 NaN
# 1              -4.42849                            1.380223
# 2              -2.47066                          -43.024959
# 3               1.63831                            9.355500
# 4               5.93325                            1.987452
#
#    previous_weeks_volume  next_weeks_open  next_weeks_close  \
# 0                    NaN            16.71             15.97
# 1            239655616.0            16.19             15.79
# 2            242963398.0            15.87             16.13
# 3            138428495.0            16.18             17.14
# 4            151379173.0            17.33             17.37
#
#    percent_change_next_weeks_price  days_to_next_dividend  \
# 0                        -4.428490                     26
# 1                        -2.470660                     19
# 2                         1.638310                     12
# 3                         5.933250                      5
# 4                         0.230814                     97
#
#    percent_return_next_dividend
# 0                      0.182704
# 1                      0.187852
# 2                      0.189994
# 3                      0.185989
# 4                      0.175029

# %% [markdown]
# # Problem 1: Creating a Scatter Plot
#
# Write a function called `scatter_plot` that takes in a stock name, and two other column names from the dow jones index data and plots a scatter plot of the two columns.
#
# For example, the function would be able to take in `'AA'`, `'open'`, and `'close'` as inputs, and it would plot the scatter plot of `'open'` and `'close'` for the `'AA'` stock.
#
# Furthermore:
#
# 1. Give the x-axis the same label as the column name inputted for `x_data`.
#
# 2. Give the y-axis the same label as the column name inputted for `y_data`.

# %%
def scatter_plot(df,stock_name,x_data,y_data):
    """
    Inputs
    ------
    df: a pandas dataframe, the dataframe containing the relevant data
    
    stock_name: a string, the name of the stock
    
    x_data: a string, the name of the first column to be used
    
    y_data: a string, the name of the second column to be used
    
    Output
    ------
    
    ax: a matplotlib.axes object
    
    """
    
    ### YOUR CODE HERE
    
    return ax

# %%
apple = df[df["stock"] == "AA"]

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=apple.date, y="open", data=apple)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=apple.date, y="close", data=apple)
plt.xticks(rotation=90)
plt.show()

# %%
my_plot = scatter_plot(df, 'AA', 'open', 'close')

# %%
assert_equal(my_plot.get_xlabel(), 'open')
assert_equal(my_plot.get_ylabel(), 'close')
assert_almost_equal(my_plot.collections[0].get_offsets()[0][0], 15.82)
assert_equal(len(my_plot.collections[0].get_offsets()), 25)

# %%
df_mat = df.values  # convert pandas to numpy multi dim array
print(df_mat[:5])
# Out:
# [[1 'AA' '1/7/2011' 15.82 16.72 15.78 16.42 239655616 3.79267 nan nan
#   16.71 15.97 -4.42849 26 0.182704]
#  [1 'AA' '1/14/2011' 16.71 16.71 15.64 15.97 242963398 -4.42849
#   1.380223028 239655616.0 16.19 15.79 -2.47066 19 0.187852]
#  [1 'AA' '1/21/2011' 16.19 16.38 15.6 15.79 138428495 -2.47066
#   -43.02495926 242963398.0 15.87 16.13 1.63831 12 0.189994]
#  [1 'AA' '1/28/2011' 15.87 16.63 15.82 16.13 151379173 1.63831
#   9.355500109 138428495.0 16.18 17.14 5.93325 5 0.185989]
#  [1 'AA' '2/4/2011' 16.18 17.39 16.18 17.14 154387761 5.93325 1.987451735
#   151379173.0 17.33 17.37 0.230814 97 0.175029]]

# %% [markdown]
# # Problem 2: Correlation of Columns
#
# In this problem you will finish writing the correlation function. The correlation function has the following parameters: `df_mat` a multidimensional array and `col1` and `col2` integer indices used to index `df_mat`.
#
# Your task is do the following:
# - Get `col1` and `col2` from `df_mat`.
# - Plot `col1` and `col2` from `df_mat` using the `scatter` function from pyplot.
#     - Your plot should have a title and labels for the x and y axis.
# - Compute the Pearson and Spearman correlations of `col1` and `col2`.
# - Lastly, your function should return:
#     - the `axes` object (we have created this for you)
#     - Pearson correlation
#     - Spearman correlation

# %%
def correlation(df_mat, col1, col2):
    
    fig, ax = plt.subplots(figsize=(10, 5))
    
    return df.corr(col1,col2)

# %%
df2 = pd.DataFrame(apple)

# %%
df2
# Out:
#      quarter stock       date   open   high    low  close     volume  \
# 0          1    AA   1/7/2011  15.82  16.72  15.78  16.42  239655616
# 1          1    AA  1/14/2011  16.71  16.71  15.64  15.97  242963398
# 2          1    AA  1/21/2011  16.19  16.38  15.60  15.79  138428495
# 3          1    AA  1/28/2011  15.87  16.63  15.82  16.13  151379173
# 4          1    AA   2/4/2011  16.18  17.39  16.18  17.14  154387761
# 5          1    AA  2/11/2011  17.33  17.48  16.97  17.37  114691279
# 6          1    AA  2/18/2011  17.39  17.68  17.28  17.28   80023895
# 7          1    AA  2/25/2011  16.98  17.15  15.96  16.68  132981863
# 8          1    AA   3/4/2011  16.81  16.94  16.13  16.58  109493077
# 9          1    AA  3/11/2011  16.58  16.75  15.42  16.03  114332562
# 10         1    AA  3/18/2011  15.95  16.33  15.43  16.11  130374108
# 11         1    AA  3/25/2011  16.38  17.24  16.26  17.09   95550392
# 360        2    AA   4/1/2011  17.13  17.80  17.02  17.47  103320396
# 361        2    AA   4/8/2011  17.42  18.47  17.42  17.92  129237024
# 362        2    AA  4/15/2011  18.06  18.19  16.38  16.52  213061090
# 363        2    AA  4/21/2011  16.36  16.97  15.88  16.97   85235391
# 364        2    AA  4/29/2011  16.94  17.24  16.66  17.00   90831895
# 365        2    AA   5/6/2011  17.27  17.96  16.83  17.15  225053559
# 366        2    AA  5/13/2011  17.16  17.62  16.75  17.10  111630753
# 367        2    AA  5/20/2011  17.00  17.29  16.26  16.26  118281015
# 368        2    AA  5/27/2011  15.96  16.48  15.83  16.48   77236662
# 369        2    AA   6/3/2011  16.73  16.83  15.77  15.92   77152591
# 370        2    AA  6/10/2011  15.92  16.03  15.17  15.28   94970970
# 371        2    AA  6/17/2011  15.29  15.50  14.59  14.72  111273573
# 372        2    AA  6/24/2011  14.67  15.60  14.56  15.23   99423717
#
#      percent_change_price  percent_change_volume_over_last_wk  \
# 0                3.792670                                 NaN
# 1               -4.428490                            1.380223
# 2               -2.470660                          -43.024959
# 3                1.638310                            9.355500
# 4                5.933250                            1.987452
# 5                0.230814                          -25.712195
# 6               -0.632547                          -30.226696
# 7               -1.766780                           66.177694
# 8               -1.368230                          -17.663150
# 9               -3.317250                            4.419900
# 10               1.003130                           14.030601
# 11               4.334550                          -26.710607
# 360              1.984820                            8.131839
# 361              2.870260                           25.083748
# 362             -8.527130                           64.860721
# 363              3.728610                          -59.994858
# 364              0.354191                            6.565939
# 365             -0.694847                          147.769309
# 366             -0.349650                          -50.398139
# 367             -4.352940                            5.957374
# 368              3.258150                          -34.700711
# 369             -4.841600                           -0.108849
# 370             -4.020100                           23.094985
# 371             -3.727930                           17.165880
# 372              3.817310                          -10.649299
#
#      previous_weeks_volume  next_weeks_open  next_weeks_close  \
# 0                      NaN            16.71             15.97
# 1              239655616.0            16.19             15.79
# 2              242963398.0            15.87             16.13
# 3              138428495.0            16.18             17.14
# 4              151379173.0            17.33             17.37
# 5              154387761.0            17.39             17.28
# 6              114691279.0            16.98             16.68
# 7               80023895.0            16.81             16.58
# 8              132981863.0            16.58             16.03
# 9              109493077.0            15.95             16.11
# 10             114332562.0            16.38             17.09
# 11             130374108.0            17.13             17.47
# 360             95550392.0            17.42             17.92
# 361            103320396.0            18.06             16.52
# 362            129237024.0            16.36             16.97
# 363            213061090.0            16.94             17.00
# 364             85235391.0            17.27             17.15
# 365             90831895.0            17.16             17.10
# 366            225053559.0            17.00             16.26
# 367            111630753.0            15.96             16.48
# 368            118281015.0            16.73             15.92
# 369             77236662.0            15.92             15.28
# 370             77152591.0            15.29             14.72
# 371             94970970.0            14.67             15.23
# 372            111273573.0            15.22             16.31
#
#      percent_change_next_weeks_price  days_to_next_dividend  \
# 0                          -4.428490                     26
# 1                          -2.470660                     19
# 2                           1.638310                     12
# 3                           5.933250                      5
# 4                           0.230814                     97
# 5                          -0.632547                     90
# 6                          -1.766780                     83
# 7                          -1.368230                     76
# 8                          -3.317250                     69
# 9                           1.003130                     62
# 10                          4.334550                     55
# 11                          1.984820                     48
# 360                         2.870260                     41
# 361                        -8.527130                     34
# 362                         3.728610                     27
# 363                         0.354191                     21
# 364                        -0.694847                     13
# 365                        -0.349650                      6
# 366                        -4.352940                     82
# 367                         3.258150                     75
# 368                        -4.841600                     68
# 369                        -4.020100                     61
# 370                        -3.727930                     54
# 371                         3.817310                     47
# 372                         7.161630                     40
#
#      percent_return_next_dividend
# 0                        0.182704
# 1                        0.187852
# 2                        0.189994
# 3                        0.185989
# 4                        0.175029
# 5                        0.172712
# 6                        0.173611
# 7                        0.179856
# 8                        0.180941
# 9                        0.187149
# 10                       0.186220
# 11                       0.175541
# 360                      0.171723
# 361                      0.167411
# 362                      0.181598
# 363                      0.176783
# 364                      0.176471
# 365                      0.174927
# 366                      0.175439
# 367                      0.184502
# 368                      0.182039
# 369                      0.188442
# 370                      0.196335
# 371                      0.203804
# 372                      0.196980

# %%
df2.corr()
# Out:
#                                      quarter      open      high       low  \
# quarter                             1.000000  0.062303  0.086098  0.032027
# open                                0.062303  1.000000  0.894101  0.832290
# high                                0.086098  0.894101  1.000000  0.926830
# low                                 0.032027  0.832290  0.926830  1.000000
# close                              -0.056794  0.694062  0.882166  0.926938
# volume                             -0.244388  0.152643  0.197490  0.018785
# percent_change_price               -0.149681 -0.366140  0.016179  0.141529
# percent_change_volume_over_last_wk  0.176753  0.262709  0.267659  0.086773
# previous_weeks_volume              -0.286471  0.011873 -0.008805 -0.001200
# next_weeks_open                    -0.105320  0.610333  0.817071  0.869052
# next_weeks_close                   -0.173202  0.353601  0.569422  0.567574
# percent_change_next_weeks_price    -0.067611 -0.344378 -0.328714 -0.397592
# days_to_next_dividend              -0.179764  0.120386  0.070243  0.131046
# percent_return_next_dividend        0.078037 -0.700135 -0.881695 -0.922596
#
#                                        close    volume  percent_change_price  \
# quarter                            -0.056794 -0.244388             -0.149681
# open                                0.694062  0.152643             -0.366140
# high                                0.882166  0.197490              0.016179
# low                                 0.926938  0.018785              0.141529
# close                               1.000000  0.000930              0.414672
# volume                              0.000930  1.000000             -0.175079
# percent_change_price                0.414672 -0.175079              1.000000
# percent_change_volume_over_last_wk  0.009998  0.604853             -0.316033
# previous_weeks_volume               0.056156  0.283360              0.062515
# next_weeks_open                     0.979134  0.055068              0.492835
# next_weeks_close                    0.692641  0.062112              0.462395
# percent_change_next_weeks_price    -0.381395  0.005971             -0.038612
# days_to_next_dividend               0.150742 -0.433191              0.038046
# percent_return_next_dividend       -0.998343 -0.014154             -0.406167
#
#                                     percent_change_volume_over_last_wk  \
# quarter                                                       0.176753
# open                                                          0.262709
# high                                                          0.267659
# low                                                           0.086773
# close                                                         0.009998
# volume                                                        0.604853
# percent_change_price                                         -0.316033
# percent_change_volume_over_last_wk                            1.000000
# previous_weeks_volume                                        -0.527938
# next_weeks_open                                               0.017965
# next_weeks_close                                              0.084107
# percent_change_next_weeks_price                               0.083034
# days_to_next_dividend                                        -0.288559
# percent_return_next_dividend                                 -0.006351
#
#                                     previous_weeks_volume  next_weeks_open  \
# quarter                                         -0.286471        -0.105320
# open                                             0.011873         0.610333
# high                                            -0.008805         0.817071
# low                                             -0.001200         0.869052
# close                                            0.056156         0.979134
# volume                                           0.283360         0.055068
# percent_change_price                             0.062515         0.492835
# percent_change_volume_over_last_wk              -0.527938         0.017965
# previous_weeks_volume                            1.000000         0.066372
# next_weeks_open                                  0.066372         1.000000
# next_weeks_close                                 0.048362         0.677483
# percent_change_next_weeks_price                 -0.028406        -0.426259
# days_to_next_dividend                           -0.141501         0.094307
# percent_return_next_dividend                    -0.069547        -0.979078
#
#                                     next_weeks_close  \
# quarter                                    -0.173202
# open                                        0.353601
# high                                        0.569422
# low                                         0.567574
# close                                       0.692641
# volume                                      0.062112
# percent_change_price                        0.462395
# percent_change_volume_over_last_wk          0.084107
# previous_weeks_volume                       0.048362
# next_weeks_open                             0.677483
# next_weeks_close                            1.000000
# percent_change_next_weeks_price             0.375200
# days_to_next_dividend                      -0.067915
# percent_return_next_dividend               -0.697087
#
#                                     percent_change_next_weeks_price  \
# quarter                                                   -0.067611
# open                                                      -0.344378
# high                                                      -0.328714
# low                                                       -0.397592
# close                                                     -0.381395
# volume                                                     0.005971
# percent_change_price                                      -0.038612
# percent_change_volume_over_last_wk                         0.083034
# previous_weeks_volume                                     -0.028406
# next_weeks_open                                           -0.426259
# next_weeks_close                                           0.375200
# percent_change_next_weeks_price                            1.000000
# days_to_next_dividend                                     -0.208665
# percent_return_next_dividend                               0.377810
#
#                                     days_to_next_dividend  \
# quarter                                         -0.179764
# open                                             0.120386
# high                                             0.070243
# low                                              0.131046
# close                                            0.150742
# volume                                          -0.433191
# percent_change_price                             0.038046
# percent_change_volume_over_last_wk              -0.288559
# previous_weeks_volume                           -0.141501
# next_weeks_open                                  0.094307
# next_weeks_close                                -0.067915
# percent_change_next_weeks_price                 -0.208665
# days_to_next_dividend                            1.000000
# percent_return_next_dividend                    -0.149016
#
#                                     percent_return_next_dividend
# quarter                                                 0.078037
# open                                                   -0.700135
# high                                                   -0.881695
# low                                                    -0.922596
# close                                                  -0.998343
# volume                                                 -0.014154
# percent_change_price                                   -0.406167
# percent_change_volume_over_last_wk                     -0.006351
# previous_weeks_volume                                  -0.069547
# next_weeks_open                                        -0.979078
# next_weeks_close                                       -0.697087
# percent_change_next_weeks_price                         0.377810
# days_to_next_dividend                                  -0.149016
# percent_return_next_dividend                            1.000000

# %%
from helper import c

col1, col2 = 6, 7
sol = c(df_mat, col1, col2)

ax, pc, sc = correlation(df_mat, col1, col2)
data = ax.collections[0].get_offsets()
print('Pearson Correlation: {0}'.format(pc[0]))
print('Spearman Correlation: {0}'.format(sc[0]))
assert_is_instance(ax, mpl.axes.Axes, msg='Return a Axes object.')  
assert_is_not(len(ax.title.get_text()), 0, msg="Your plot doesn't have a title.")
assert_is_not(ax.xaxis.get_label_text(), '', msg="Change the x-axis label to something more descriptive.")
assert_is_not(ax.yaxis.get_label_text(), '', msg="Change the y-axis label to something more descriptive.")

assert_equal(np.array_equal(data[:,0], sol[0]), True, msg="Data on for the x axis is not correct")
assert_equal(np.array_equal(data[:,1], sol[1]), True, msg="Data on for the y axis is not correct")

assert_almost_equal(pc[0], sol[2][0])
assert_almost_equal(sc[0], sol[3][0])

# %% [markdown]
# # Problem 3: Fitting OLS Model to Data
#
# Your task is to finish writing the `reg_plot` function. Your task is to fit an OLS model to 2 columns of data. `reg_plot` takes in the following parameters:
#
# - a **dataframe** (not numpy multidimensional array),
# - `x` and `y`, which are strings that specify the name of a column in the DataFrame.
#
# Use the `regplot` function from the Seaborn library to fit an ols model to the data. Your plot should contain a label for the x and y axis and also a title.

# %%
def reg_plot(df, x, y):
    '''
    df dataframe
    
    x: column name
    
    y: column name
    '''
    
    ### YOUR CODE HERE
    
    return ax

# %%
sns.regplot(x="open",y="close", data=apple)
plt.show()

# %%
ax = reg_plot(df, x='open', y='close')
from helper import rp
sol_x, sol_y = rp(df)
assert_is_instance(ax, mpl.axes.Axes, msg='Return a Axes object.')  
assert_is_not(len(ax.title.get_text()), 0, msg="Your plot doesn't have a title.")
assert_is_not(ax.xaxis.get_label_text(), '', msg="Change the x-axis label to something more descriptive.")
assert_is_not(ax.yaxis.get_label_text(), '', msg="Change the y-axis label to something more descriptive.")
assert_equal(np.array_equal(ax.lines[0].get_ydata(), sol_y), True, msg="Data on Y-Axis is incorrect")
assert_equal(np.array_equal(ax.lines[0].get_xdata(), sol_x), True, msg="Data on x-axis is incorrect")
sol_x, sol_y = rp(df, 'high', 'volume')
assert_is_instance(ax, mpl.axes.Axes, msg='Return a Axes object.')  
assert_is_not(len(ax.title.get_text()), 0, msg="Your plot doesn't have a title.")
assert_is_not(ax.xaxis.get_label_text(), '', msg="Change the x-axis label to something more descriptive.")
assert_is_not(ax.yaxis.get_label_text(), '', msg="Change the y-axis label to something more descriptive.")
assert_equal(np.array_equal(ax.lines[0].get_ydata(), sol_y), True, msg="Data on x axis is incorrect")
assert_equal(np.array_equal(ax.lines[0].get_xdata(), sol_x), True, msg="Data on y axis is incorrect")

# %% [markdown]
# **&copy; 2017: Robert J. Brunner at the University of Illinois.**
#
# This notebook is released under the [Creative Commons license CC BY-NC-SA 4.0][ll]. Any reproduction, adaptation, distribution, dissemination or making available of this notebook for commercial use is not allowed unless authorized in writing by the copyright holder.
#
# [ll]: https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode
